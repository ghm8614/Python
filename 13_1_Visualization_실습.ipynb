# %% [markdown]
# <a href="https://colab.research.google.com/github/ghm8614/Python/blob/main/13_1_Visualization_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 13-1 Visualization 실습

# %% [markdown]
# ## 실습 1 : 선 그래프 그리기

# %%
import pandas as pd

scores = [[84,87,78],[21,15,84],[87,84,76],[100,87,99],[59,99,59],[46,77,56]]
names = ['철수','영이','길동','미영','순이','철이']
lectures = ['국어','수학','영어']

d2 = pd.DataFrame(scores,index=names,columns=lectures)
d2
# Out:
#      국어  수학  영어
# 철수   84  87  78
# 영이   21  15  84
# 길동   87  84  76
# 미영  100  87  99
# 순이   59  99  59
# 철이   46  77  56

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,2))  # 최초 창의 크기 설정가능

sub_kor = fig.add_subplot(1,3,1)   # add_subplot(그래프의 행개수,열개수,번째)
sub_eng = fig.add_subplot(1,3,2)
sub_math = fig.add_subplot(1,3,3)

sub_kor.plot(d2.index,df['국어'])
sub_eng.plot(d2.index,df['영어'])
sub_math.plot(d2.index,df['수학'])

sub_kor.set_title('국어성적')    # sbuplot은 set_title()함수 이용
sub_eng.set_title('영어성적')
sub_math.set_title('수학성적')

plt.show()

# %% [markdown]
# ## 실습 2 : 세로 막대 그래프 그리기

# %%
import matplotlib.pyplot as plt

d2['국어'].plot(kind = 'bar') 
# = plt.bar(names,d2['국어'],width=0.5) # 막대의 폭 설정가능

plt.title('국어성적')         
plt.xlabel('이름')
plt.ylabel('점수')

plt.show()

# %% [markdown]
# ## 실습 3 : 가로 막대 그래프 그리기

# %%
# 왜 내림차순이 아니고 오름차순인가 (barh는 그래프를 아래부터 쌓아서 그리기 때문에)
import pandas as pd
import matplotlib.pyplot as plt

d3 = d2.sort_values(by='수학',ascending=True)   # 정렬 후, 그래프그리기

d3['수학'].plot(kind='barh')
# = plt.barh(names,d3['수학'],height=0.5)   # 가로막대랑 다름(y축,x축,height = )

plt.title('수학성적')
plt.xlabel('점수')
plt.ylabel('이름')

plt.show()

# %% [markdown]
# ## 실습 4 : 히스토그램 그리기

# %%
# tips 데이터 파악
import seaborn as sns
tips = sns.load_dataset('tips')   # 샘플데이터셋명
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')   
#print(tips.head())

plt.style.use('ggplot')   # 격자무늬

tips['total_bill'].plot(kind='hist', bins =10, color = 'b',figsize = (5,3))
# = sns.distplot(tips['total_bill'],color='b',kde=False)

plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ## 실습 5 : 산점도 그리기

# %%
# laber을 지정하지 않아도 기본값으로 생성됨
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

plt.style.use('default')    # 격자무늬 해제
tips.plot(kind='scatter',x='total_bill',y='tip',s = 10,figsize=(5,3))# s:점크기

plt.title('Scatterplot of Total Bill VS Tip')

plt.show()

# %% [markdown]
# ## 실습 6 : 박스 플롯 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.figure(figsize=(4.5,2.5))
plt.style.use('default')
plt.boxplot(x = [tips[tips['sex']=='Female']['tip'],
                 tips[tips['sex']=='Male']['tip']], labels=['Female','Male'])
plt.title('Boxplot of Tips Sex')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## 실습 7 : 회귀선이 있는 산포도 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.figure(figsize=(4,2))
sns.regplot(data=tips, x='size',y='tip',truncate=False)#truncate=False:범위조정

plt.title('Scatterplot of Tip and Headcount')
plt.xlabel('HeadCount')

plt.show()

# %% [markdown]
# ## 실습 8 : 회귀선이 있는 산점도 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.style.use('default')
sns.lmplot(data=tips, x='total_bill',y='tip',hue='smoker',truncate=False,size=3)

plt.title('Scatterplot of Total Bill and Tip')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 실습 9 : 히스토그램&커널 밀도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.figure(figsize=(5,3))
sns.distplot(tips['total_bill'])

plt.title('Histogram/Kernel Density Estimation of Total Bill')
plt.ylabel('')   # y축에 공백 만들고 싶을 경우

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 실습 10 : 빈도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.figure(figsize=(5,3))
sns.countplot(x='day',palette='Set2',data=tips)

plt.title('Count of days')
plt.xlabel('Day of the Week')
plt.ylabel('Frequancy')

plt.show()

# %% [markdown]
# ## 실습 11 : 바이올린 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

plt.figure(figsize=(5,3))
sns.violinplot(x='time',y='total_bill',data=tips)

plt.title('Violin plot of total bill by time of day')

plt.show()

# %% [markdown]
# ## 실습 12 : 화면 분할하여 히스토그램$커널 밀도 그래프 그리기

# %%
# subplot을 사용할 것인가 FaceGrid를 사용할 것인가
# 무엇을 기준으로 행과 열로 화면을 분할할 것인가
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

g = sns.FacetGrid(data=tips,col='time',size=3)
g = g.map(sns.distplot,'total_bill') 
# distplot함수의 형태를 가져와서 total_bill값을 넣어라
# g.set_axis_labels('xxx','yyy') : 화면 분할에서 xlabel,ylabel 설정하기

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 실습 13 : 화면 분할 산점도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

g = sns.FacetGrid(data=tips,col='time',row='smoker',size=2.5)
g = g.map(plt.scatter,'total_bill','tip')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')  

g = sns.FacetGrid(data=tips,col='time',row='smoker',hue='sex',size=2.5)
g = g.map(plt.scatter,'total_bill','tip')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
